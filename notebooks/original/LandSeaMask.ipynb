# %% [markdown]
# # Arctic "Land-Sea Mask" ERA-5 variable

# %%
# Libraries for working with multidimensional arrays
import numpy as np
import xarray as xr

# Libraries for plotting and visualising data
import matplotlib.path as mpath
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature


import os
import sys
import json
from zipfile import ZipFile
import time
import base64
from IPython.core.display import HTML

import requests
import warnings
warnings.filterwarnings('ignore')

# %%
pip install -U hda
# Out:
# Requirement already satisfied: hda in c:\users\zaca1262\appdata\local\anaconda3\lib\site-packages (2.17)
# Requirement already satisfied: requests>=2.5.0 in c:\users\zaca1262\appdata\local\anaconda3\lib\site-packages (from hda) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\zaca1262\appdata\local\anaconda3\lib\site-packages (from hda) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\zaca1262\appdata\local\anaconda3\lib\site-packages (from requests>=2.5.0->hda) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zaca1262\appdata\local\anaconda3\lib\site-packages (from requests>=2.5.0->hda) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zaca1262\appdata\local\anaconda3\lib\site-packages (from requests>=2.5.0->hda) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zaca1262\appdata\local\anaconda3\lib\site-packages (from requests>=2.5.0->hda) (2024.6.2)
# Requirement already satisfied: colorama in c:\users\zaca1262\appdata\local\anaconda3\lib\site-packages (from tqdm->hda) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import tqdm
from hda import Client, Configuration

# %%
dataset_id = "EO:ECMWF:DAT:REANALYSIS_ERA5_SINGLE_LEVELS_MONTHLY_MEANS"

# %%
{
  "dataset_id": "EO:ECMWF:DAT:REANALYSIS_ERA5_SINGLE_LEVELS_MONTHLY_MEANS",
  "itemsPerPage": 200,
  "startIndex": 0
}
# Out:
# {'dataset_id': 'EO:ECMWF:DAT:REANALYSIS_ERA5_SINGLE_LEVELS_MONTHLY_MEANS',
#  'itemsPerPage': 200,
#  'startIndex': 0}

# %%
data = {
  "dataset_id": "EO:ECMWF:DAT:REANALYSIS_ERA5_SINGLE_LEVELS_MONTHLY_MEANS",
  "product_type": [
    "2m_Temperature" "monthly_averaged_reanalysis"
  ],
  "variable": [
    "Land-sea mask"
  ],
  "year": [
    "1979",
    "1980",
    "1981",
    "1982",
    "1983",
    "1984",
    "1985",
    "1986",
    "1987",
    "1988",
    "1989",
    "1990",
    "1991",
    "1992",
    "1993",
    "1994",
    "1995",
    "1996",
    "1997",
    "1998",
    "1999",
    "2000",
    "2001",
    "2002",
    "2003",
    "2004",
    "2005",
    "2006",
    "2007",
    "2008",
    "2009",
    "2010",
    "2011",
    "2012",
    "2013",
    "2014",
    "2015",
    "2016",
    "2017",
    "2018",
    "2019",
    "2020",
    "2021",
    "2022",
    "2023",
    "2024"
      ],
  
  "month": [
    "01",
    "02",
    "03",
    "04",
    "05",
    "06",
    "07",
    "08",
    "09",
    "10", 
    "11",
    "12"],
  "time": [
    "00:00"
  ],
  "bbox": [
    -180,
    90,
    180,
    60
  ],
  "format": "netcdf",
  "itemsPerPage": 200,
  "startIndex": 0
}

# %%
conf = Configuration(user = "zcasty", password = "green1234Zaria")
#hda_client = Client(config = conf)
#c = Client(debug=True)
c = Client(config=conf, max_workers=12)
matches = c.search(data)
print(matches)
matches.download()
# Out:
# SearchResults[items=1,volume=ND]

# %%
data
# Out:
# {'dataset_id': 'EO:ECMWF:DAT:REANALYSIS_ERA5_SINGLE_LEVELS_MONTHLY_MEANS',
#  'product_type': ['2m_Temperaturemonthly_averaged_reanalysis'],
#  'variable': ['Land-sea mask'],
#  'year': ['1979',
#   '1980',
#   '1981',
#   '1982',
#   '1983',
#   '1984',
#   '1985',
#   '1986',
#   '1987',
#   '1988',
#   '1989',
#   '1990',
#   '1991',
#   '1992',
#   '1993',
#   '1994',
#   '1995',
#   '1996',
#   '1997',
#   '1998',
#   '1999',
#   '2000',
#   '2001',
#   '2002',
#   '2003',
#   '2004',
#   '2005',
#   '2006',
#   '2007',
#   '2008',
#   '2009',
#   '2010',
#   '2011',
#   '2012',
#   '2013',
#   '2014',
#   '2015',
#   '2016',
#   '2017',
#   '2018',
#   '2019',
#   '2020',
#   '2021',
#   '2022',
#   '2023',
#   '2024'],
#  'month': ['01',
#   '02',
#   '03',
#   '04',
#   '05',
#   '06',
#   '07',
#   '08',
#   '09',
#   '10',
#   '11',
#   '12'],
#  'time': ['00:00'],
#  'bbox': [-180, 90, 180, 60],
#  'format': 'netcdf',
#  'itemsPerPage': 100,
#  'startIndex': 0}

# %%
# get filename of latest .nc downloaded file 
files = [file for file in os.listdir(".") if (file.lower().endswith('.nc'))]
list_nc_file = []

for file in sorted(files,key=os.path.getmtime, reverse=True):
    list_nc_file.append(file)
    
print(f'Selected netCDF file: {list_nc_file[0]}')
# Out:
# Selected netCDF file: reanalysis-era5-single-levels-monthly-means-215aeae5bf40dc9b6bbd0738c97f7a3d.nc

# %%
# load file in WEkEO API
t2m = list_nc_file[0]

# %%
# Create Xarray Dataset
ds = xr.open_dataset(lsm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Create Xarray Dataset
# ----> 2 ds = xr.open_dataset(lsm)
#
# NameError: name 'lsm' is not defined

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 1440, latitude: 121, expver: 2, time: 546)
# Coordinates:
#   * longitude  (longitude) float32 -180.0 -179.8 -179.5 ... 179.2 179.5 179.8
#   * latitude   (latitude) float32 90.0 89.75 89.5 89.25 ... 60.5 60.25 60.0
#   * expver     (expver) int32 1 5
#   * time       (time) datetime64[ns] 1979-01-01 1979-02-01 ... 2024-06-01
# Data variables:
#     sf         (time, expver, latitude, longitude) float32 ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-07-08 15:41:48 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...

# %%
ds.where(ds.lsm==1).mean(),ds.where(ds.lsm==0).mean(), ds.mean()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 ds.where(ds.lsm==1).mean(),ds.where(ds.lsm==0).mean(), ds.mean()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xarray\core\common.py:278, in AttrAccessMixin.__getattr__(self, name)
#     276         with suppress(KeyError):
#     277             return source[name]
# --> 278 raise AttributeError(
#     279     f"{type(self).__name__!r} object has no attribute {name!r}"
#     280 )
#
# AttributeError: 'Dataset' object has no attribute 'lsm'

# %%
yearly_mean = da.groupby('time.year').mean('time')
yearly_mean_ocean = da_ocean.groupby('time.year').mean('time')
yearly_mean_land = da_land.groupby('time.year').mean('time')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 yearly_mean = da.groupby('time.year').mean('time')
#       2 yearly_mean_ocean = da_ocean.groupby('time.year').mean('time')
#       3 yearly_mean_land = da_land.groupby('time.year').mean('time')
#
# NameError: name 'da' is not defined
